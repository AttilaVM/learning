# %% [markdown]
# ![](./pagila_schema.png)

# %%
import pandas as ps
import getpass
import os

user = os.getenv("PGUSER") if os.getenv("PGUSER") is not None else input()
password = os.getenv("PGPASSWORD") if os.getenv("PGPASSWORD") is not None else getpass.getpass()
server = "10.100.120.151"
port = "5432"
database = "pagila"
driver = "postgres_utf8"
connection_string = f"postgresql://{user}:{password}@{server}/{database}"

# %%
# %load_ext sql
# %sql $connection_string
# %config SqlMagic.autopandas=True
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
#

# %% [markdown]
# List all schemas

# %%
# %sql \dn
# Out:
#  * postgresql://attila.molnar:***@10.100.120.151/pagila
# 1 rows affected.
#      Name     Owner
# 0  public  postgres

# %% [markdown]
# List all tables in the currently active schema (public by default)

# %%
# %sql \dt
# Out:
#  * postgresql://attila.molnar:***@10.100.120.151/pagila
# 21 rows affected.
#     Schema              Name   Type     Owner
# 0   public             actor  table  postgres
# 1   public           address  table  postgres
# 2   public          category  table  postgres
# 3   public              city  table  postgres
# 4   public           country  table  postgres
# 5   public          customer  table  postgres
# 6   public              film  table  postgres
# 7   public        film_actor  table  postgres
# 8   public     film_category  table  postgres
# 9   public         inventory  table  postgres
# 10  public          language  table  postgres
# 11  public           payment  table  postgres
# 12  public  payment_p2007_01  table  postgres
# 13  public  payment_p2007_02  table  postgres
# 14  public  payment_p2007_03  table  postgres
# 15  public  payment_p2007_04  table  postgres
# 16  public  payment_p2007_05  table  postgres
# 17  public  payment_p2007_06  table  postgres
# 18  public            rental  table  postgres
# 19  public             staff  table  postgres
# 20  public             store  table  postgres

# %% [markdown]
# Describe the film table

# %%
# %sql \d film
# Out:
#  * postgresql://attila.molnar:***@10.100.120.151/pagila
# 14 rows affected.
#                   Column                         Type  \
# 0                film_id                      integer
# 1                  title       character varying(255)
# 2            description                         text
# 3           release_year                         year
# 4            language_id                     smallint
# 5   original_language_id                     smallint
# 6        rental_duration                     smallint
# 7            rental_rate                 numeric(4,2)
# 8                 length                     smallint
# 9       replacement_cost                 numeric(5,2)
# 10                rating                  mpaa_rating
# 11           last_update  timestamp without time zone
# 12      special_features                       text[]
# 13              fulltext                     tsvector
#
#                                             Modifiers
# 0    not null default nextval('film_film_id_seq'::...
# 1                                            not null
# 2
# 3
# 4                                            not null
# 5
# 6                                  not null default 3
# 7                               not null default 4.99
# 8
# 9                              not null default 19.99
# 10                           default 'G'::mpaa_rating
# 11                             not null default now()
# 12
# 13                                           not null

# %% [markdown]
# # Fulltext Search

# %%
# %%sql
#
# SELECT
#     fulltext
# FROM
#     film
# WHERE
#     fulltext @@ to_tsquery('fate&india');
# Out:
#  * postgresql://attila.molnar:***@10.100.120.151/pagila
# 3 rows affected.
#                                             fulltext
# 0  'administr':17 'ancient':19 'antitrust':1 'dat...
# 1  'ancient':19 'chef':17 'easi':1 'fate':4 'girl...
# 2  'ancient':19 'charact':5 'dog':12 'fate':4 'fe...
